# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
import numpy as np
import os
rn = np.random.rand(100)

nomefold = "ex5folder"
dirname = os.path.join(os.path.abspath(os.getcwd()),nomefold)
if not os.path.exists(dirname):
    os.mkdir(dirname)
filename = os.path.join(dirname,"simple_data.txt")
np.savetxt(filename,rn)
#print(np.loadtxt(filename))

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
r5x5 = np.random.rand(5,5)

nomefold = "ex5folder"
dirname = os.path.join(os.path.abspath(os.getcwd()),nomefold)
if not os.path.exists(dirname):
    os.mkdir(dirname)
filename = os.path.join(dirname,"data.txt")
np.savetxt(filename,r5x5)

#print(np.loadtxt(filename))

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
import numpy as np
import csv
import os

# Carica il file txt
load = np.loadtxt(filename)

# Nuovo file CSV
newfilename = os.path.join(dirname, "file_transformed.csv")

# Scrivi il CSV correttamente
with open(newfilename, "w", newline='') as f:
    writer = csv.writer(f, delimiter=",")
    for row in load:
        writer.writerow(row)

# Ricarica il CSV per verificarlo
#print(np.loadtxt(newfilename, delimiter=","))

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
namefile = "credit_card.dat"
carta = []
carte = []
word_size = 6
with open(namefile,"rb") as file:
    for line in file:
        for i in range(0,len(line)-6,word_size):
            carta.append(chr(int(line[i:i+word_size],base=2)))
        carte.append("".join(carta[:]))
        carta = []
print(carte)
# Out:
# ['7648 5673 3775 2271', '3257 8247 3354 2266', '2722 0001 4011 6652', '0661 3063 3742 3150', '0432 1608 1462 4742', '5827 2027 8785 7303', '5774 8528 2087 1117', '8140 1210 6352 2845', '5764 1133 7301 7100', '6456 1737 4126 6726', '1228 8631 7382 0000', '7051 0160 5374 3166', '0618 3587 1630 6376', '1545 5454 7444 5636', '6735 3116 3202 6834', '7287 5011 1547 8413', '7033 2607 3328 4200', '2568 5244 1874 5024', '1684 2253 7570 7118', '0672 2576 0575 6631', '6332 8353 8787 1340', '1813 3361 1175 4211', '2477 6450 8840 2368', '5512 3505 2563 1326', '3083 7882 0621 0025', '4521 5148 8045 0334', '7563 3654 8713 5787', '8324 2664 0476 5561', '0565 2504 7168 3510', '5107 5507 1767 0738', '2462 1821 2448 1443', '2788 0638 6861 6554', '5851 5873 5474 0547', '0670 1004 4013 2655', '5874 5506 3048 0806', '2805 5401 8462 1260', '5083 8406 6310 1862', '1076 1445 3013 2266', '8440 4804 4844 5277', '4758 6141 0686 1387', '7586 0675 0315 2568', '2544 1258 7432 5165', '3474 5023 4434 5626', '1410 02
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
import csv
namefile = "user_data.json"

file = json.load(open(namefile,"r"))
dictionary=[]
for i in range(len(file)):
        if (file[i]['CreditCardType']=="American Express"): dictionary.append(file[i]) 
f = open("amexpress.csv","w")
w = csv.DictWriter(f,dictionary[0].keys())
for i in dictionary:
        w.writerow(i)
f.close()

# %%
import json
import csv

namefile = "user_data.json"

with open(namefile, "r") as f:
    file_data = json.load(f)

amex_users = []
for item in file_data:
    if item.get('CreditCardType') == "American Express": 
        amex_users.append(item)

if amex_users:

    with open("amexpress.csv", "w", newline='', encoding='utf-8') as f:
        keys = amex_users[0].keys()
        
        w = csv.DictWriter(f, fieldnames=keys)
        
        w.writeheader()

        w.writerows(amex_users)
        
    print(f"File salvato con successo: {len(amex_users)} utenti esportati.")
else:
    print("Nessun utente American Express trovato.")
# Out:
# File salvato con successo: 20 utenti esportati.

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe what you see

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
#df = pd.read_csv("https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1")
a = df["class"]
#print(df.head(),a)

# The column identifies a class with two possible values, 0 or 1, almost equally distributed

plt.hist(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 import numpy as np
#       4 #df = pd.read_csv("https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1")
# ----> 5 a = df["class"]
#       6 #print(df.head(),a)
#       7
#       8 # The column identifies a class with two possible values, 0 or 1, almost equally distributed
#      10 plt.hist(a)
#
# NameError: name 'df' is not defined

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
import pandas as pd
from itertools import permutations as prt
from matplotlib import pyplot as plt
a = pd.read_csv("https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1")
#print(a.head())

names = ["features_1","features_3","features_2"]
for i,j in prt(names,2):
    plt.scatter(a[i],a[j])
    plt.grid()
    plt.show()

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
#list(a["features_1"])

# %%
import pandas as pd
from itertools import permutations as prt

#a = pd.read_csv("https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1")

data = {
    "features_1" : list(a["features_1"]),
    "features_2" : list(a["features_2"]),
    "features_3" : list(a["features_3"])
        }

with open("features_data.json","w") as file:
    json.dump(data,file)
